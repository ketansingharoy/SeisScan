# %%
import sys
import os
import json
from obspy import UTCDateTime

path = '../code'
sys.path.insert(0, path)

import SeisScan as ss

# %% [markdown]
# # Prepare SDS

# %%
provider = 'IRISPH5'
starttime = UTCDateTime('2016-07-11 05:50:00')
endtime = UTCDateTime('2016-07-11 06:05:00')

network = 'YW'
station = '1001'
location = ''
channel = 'DP?'

minlongitude = -97.74814955
maxlongitude = -97.58986945000001
minlatitude = 36.59136195
maxlatitude = 36.63890505

db_dir = '../data'

ss.make_sds_from_fdsn(provider, starttime, endtime, network, station, location, channel,
            minlongitude, maxlongitude, minlatitude, maxlatitude, db_dir)
# Out:
# [2024-06-22 23:18:43,035] - obspy.clients.fdsn.mass_downloader - INFO: Initializing FDSN client(s) for IRISPH5.
# [2024-06-22 23:18:43,966] - obspy.clients.fdsn.mass_downloader - INFO: Successfully initialized 1 client(s): IRISPH5.
# [2024-06-22 23:18:43,969] - obspy.clients.fdsn.mass_downloader - INFO: Total acquired or preexisting stations: 0
# [2024-06-22 23:18:43,970] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRISPH5' - Requesting unreliable availability.
# [2024-06-22 23:18:44,221] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRISPH5' - Successfully requested availability (0.25 seconds)
# [2024-06-22 23:18:44,222] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRISPH5' - Found 1 stations (3 channels).
# [2024-06-22 23:18:44,222] - obspy.clients.fdsn.mass_downloader - INFO: Client 'IRISPH5' - Will attempt to download data from 1 stations.
# ...
